# %% [markdown]
# ## import

# %%
import cv2
import numpy as np
from skimage import data

cv2.__version__
# Out:
# '4.1.1'

# %%
# extra
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Image

# %%
cat = data.chelsea()
astro = data.astronaut()

# %%
cat.shape
# Out:
# (300, 451, 3)

# %%
astro.shape
# Out:
# (512, 512, 3)

# %%
type(astro)
# Out:
# numpy.ndarray

# %%
cv2.imshow("cat" , cat)
cv2.waitKey();
cv2.destroyAllWindows();

# %%
plt.imshow(cat)

# %%
img = cv2.imread('test.jpg')

plt.imshow(img , interpolation='bicubic')

plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
cat_cv = cv2.cvtColor(cat, cv2.COLOR_RGB2BGR)
astro_cv = cv2.cvtColor(astro, cv2.COLOR_RGB2BGR)
cat_gray = cv2.cvtColor(cat, cv2.COLOR_RGB2GRAY)

cv2.imshow("cat_cv" , cat_cv)
cv2.imshow("astro_cv" , astro_cv)
cv2.imshow("cat_gray" , cat_gray)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cat_gray.shape
# Out:
# (300, 451)

# %%
#jpg image
cv2.imwrite("test.jpg" , astro_cv)
cv2.imwrite("cat.tif" , cat_cv)
# Out:
# True

# %%
img = cv2.imread('cat.tif')
img_cv = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
#plt.subplot(1)
plt.imshow(img_cv,cmap=plt.cm.gray)
#plt.subplot(1)
#plt.imshow(img_cv,cmap="gray")
