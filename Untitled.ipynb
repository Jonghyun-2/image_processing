# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
x = np.array(range(1,100))
w = 4*np.pi/len(x)
w_x =w *x
cos_x = np.cos(w*x)
sin_x = np.cos(w*x - np.pi/2)

# %%
plt.plot(w_x,cos_x,color = "red")
plt.plot(w_x,sin_x,color = "green")
plt.grid()
